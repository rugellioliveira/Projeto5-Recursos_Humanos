# %% [markdown]
# <a href="https://colab.research.google.com/github/rugellioliveira/Projeto5-Recursos_Humanos/blob/main/Projeto_5(Recursos_Humanos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aqui vamos analisar Dados referentes a recursos humanos, em especial tempo de experiência x salário**
#
# ![image.png](data:image/png;base64,...)
#
# Download dos Dados: https://www.kaggle.com/datasets/karthickveerakumar/salary-data-simple-linear-regression?datasetId=10624&sortBy=voteCount

# %%
# Importar bibliotecas

# Bibliotecas para Modelagem e Matrizes
import numpy as np
import pandas as pd

# Bibliotecas para análises gráficas
import matplotlib.pyplot as plt
import seaborn as sns

# Bibliotecas para ignorar avisos
import warnings

# Desabilitando avisos
warnings.filterwarnings('ignore')

# %%
# Leitura dos Dados
Base_Dados = pd.read_csv('Salary_Data.csv')

# Cabeçalho
Base_Dados.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Renomenado as colunas
Base_Dados.rename( columns={
    'YearsExperience' : 'Xp',
    'Salary' : 'Renda'
}, inplace=True )

# %%
# Dimensão
Base_Dados.shape
# Out:
# (30, 2)

# %%
# Campos nulos
Base_Dados.isnull().sum()
# Out:
# Xp       0
# Renda    0
# dtype: int64

# %%
# Gráfico Campos Nulos
sns.heatmap( Base_Dados.isnull(), cbar=False );

# %%
# Informações Estatísticas
Base_Dados.describe()
# Out:
#               Xp          Renda
# count  30.000000      30.000000
# mean    5.313333   76003.000000
# std     2.837888   27414.429785
# min     1.100000   37731.000000
# 25%     3.200000   56720.750000
# 50%     4.700000   65237.000000
# 75%     7.700000  100544.750000
# max    10.500000  122391.000000

# %%
plt.figure( figsize=(10, 6) )
plt.title('Análise da Renda')
sns.kdeplot( Base_Dados['Renda'], color='green' );

# %%
plt.figure( figsize=(10, 6) )
plt.title('Análise da Xp')
sns.kdeplot( Base_Dados['Xp'], color='blue' );

# %%
# Distribuição
plt.figure( figsize=(10, 5) )
sns.boxplot( Base_Dados['Renda'] );

# %%
# Distribuição
plt.figure( figsize=(10, 5) )
sns.boxplot( Base_Dados['Xp'] );

# %%
# Distribuição
plt.figure( figsize=(10, 5) )
sns.scatterplot( data=Base_Dados, x='Renda', y='Xp');

# %%
plt.figure( figsize=(10, 5) )
sns.regplot( data=Base_Dados, x='Renda', y='Xp');

# %%
# Correlação
Correlacao = Base_Dados.corr('pearson')
plt.figure( figsize=(10, 5) )
sns.heatmap( Correlacao, annot=True, cbar=True );

# %%
# Correlação
Correlacao = Base_Dados.corr('spearman')
plt.figure( figsize=(10, 5) )
sns.heatmap( Correlacao, annot=True, cbar=True );
